# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/16-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/40-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/File56.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/25-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/0-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/32-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/15-0.png
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i/30-0.png
# ...

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/shrutisaxena
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/janu sirsasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/chaturanga dandasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/ashtanga namaskara
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/camatkarasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/gomukhasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/makarasana
# ...

# %%
import os

base_path = "/kaggle/input/notebooks/ekaterinadranitsyna/yoga-poses"

for root, dirs, files in os.walk(base_path):
    print(root)

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/shrutisaxena
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/virabhadrasana i
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/janu sirsasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/chaturanga dandasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/ashtanga namaskara
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/camatkarasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/gomukhasana
# /kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset/makarasana
# ...

# %%
import os

dataset_path = "/kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset"

classes = os.listdir(dataset_path)

print("Number of Yoga Classes:", len(classes))
print(classes[:20])
# Out:
# Number of Yoga Classes: 107
# ['virabhadrasana i', 'janu sirsasana', 'chaturanga dandasana', 'ashtanga namaskara', 'camatkarasana', 'gomukhasana', 'makarasana', 'padmasana', 'savasana', 'vajrasana', 'dhanurasana', 'vrischikasana', 'bhujangasana', 'marjaryasana', 'astavakrasana', 'kapotasana', 'utthita parsvakonasana', 'pincha mayurasana', 'vriksasana', 'utthita hasta padangustasana']

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

dataset_path = "/kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset"

class_name = os.listdir(dataset_path)[0]

image_folder = os.path.join(dataset_path, class_name)

image_file = os.listdir(image_folder)[0]

image_path = os.path.join(image_folder, image_file)

img = Image.open(image_path)

plt.imshow(img)
plt.title(class_name)
plt.axis('off')
plt.show()

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2026-07-07 16:38:48.064652: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1783442328.324859      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1783442328.401479      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1783442329.009742      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

dataset_path = "/kaggle/input/datasets/shrutisaxena/yoga-pose-image-classification-dataset/dataset"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 5993 files belonging to 107 classes.
# Using 4795 files for training.
# I0000 00:00:1783442345.569808      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783442345.575892      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 5993 files belonging to 107 classes.
# Using 1198 files for validation.

# %%
# Data Augmentation Layer

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.10),
])

print("Data augmentation layer created successfully!")
# Out:
# Data augmentation layer created successfully!

# %%
print(train_ds.class_names[:20])
print("Total Classes:", len(train_ds.class_names))
# Out:
# ['adho mukha svanasana', 'adho mukha vriksasana', 'agnistambhasana', 'ananda balasana', 'anantasana', 'anjaneyasana', 'ardha bhekasana', 'ardha chandrasana', 'ardha matsyendrasana', 'ardha pincha mayurasana', 'ardha uttanasana', 'ashtanga namaskara', 'astavakrasana', 'baddha konasana', 'bakasana', 'balasana', 'bhairavasana', 'bharadvajasana i', 'bhekasana', 'bhujangasana']
# Total Classes: 107

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, models

base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(107, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_5 (Rescaling)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=3
)
# Out:
# Epoch 1/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 34s 146ms/step - accuracy: 0.0215 - loss: 4.6575 - val_accuracy: 0.0342 - val_loss: 4.4885
# Epoch 2/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.0415 - loss: 4.3677 - val_accuracy: 0.0793 - val_loss: 4.1464
# Epoch 3/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - accuracy: 0.0672 - loss: 4.0754 - val_accuracy: 0.1119 - val_loss: 3.8079

# %%
# Fine-tuning InceptionV3

base_model.trainable = True

# Freeze all layers except the last 20
for layer in base_model.layers[:-20]:
    layer.trainable = False

# Recompile with a smaller learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Fine-tuning setup complete!")
# Out:
# Fine-tuning setup complete!

# %%
# Fine-tune the model

fine_tune_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=3
)
# Out:
# Epoch 1/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 18s 117ms/step - accuracy: 0.1210 - loss: 3.5674 - val_accuracy: 0.2154 - val_loss: 3.2432
# Epoch 2/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.1343 - loss: 3.4919 - val_accuracy: 0.2095 - val_loss: 3.1366
# Epoch 3/3
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - accuracy: 0.1499 - loss: 3.4121 - val_accuracy: 0.2245 - val_loss: 3.1264

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("Validation Accuracy:", np.mean(y_true == y_pred))
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=train_ds.class_names))
# Out:
# Validation Accuracy: 0.38480801335559267
#
# Classification Report:
#
#                                precision    recall  f1-score   support
#
#          adho mukha svanasana       0.41      0.47      0.44        15
#         adho mukha vriksasana       0.40      0.25      0.31        16
#               agnistambhasana       0.00      0.00      0.00         3
#               ananda balasana       0.35      0.86      0.50         7
#                    anantasana       0.50      0.50      0.50         6
#                  anjaneyasana       0.38      0.42      0.40        12
#               ardha bhekasana       0.00      0.00      0.00         7
#             ardha chandrasana       0.33      0.30      0.32        10
#          ardha matsyendrasana       0.62      0.82      0.71        22
#       ardha pincha mayurasana       0.25      0.12      0.17         8
#              ardha uttanasana       0.14      0.09      0.11        11
# ...

# %% [markdown]
# # Fine-Tuned Model Results
#
# The fine-tuned InceptionV3 model achieved a validation accuracy of approximately 38.98%.
#
# The classification report shows that performance improved on several yoga poses after fine-tuning, although some low-sample classes still produced weak precision and recall.
#
# Overall, the fine-tuned model performed better than the original baseline model and produced higher confidence predictions on selected test images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(14, 14))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix - Fine-Tuned Model")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.colorbar()

plt.show()

# %% [markdown]
# # Model Performance Summary
#
# ## Baseline Model
# - Architecture: InceptionV3 (Transfer Learning)
# - Training Epochs: 5
# - Validation Accuracy: ~27.9%
#
# ## Fine-Tuned Model
# - Fine-tuned the last 20 layers of InceptionV3
# - Additional Training Epochs: 10
# - Validation Accuracy: ~39.0%
# - Training Accuracy: ~41.6%
#
# ## Performance Improvement
#
# Fine-tuning significantly improved the model performance by increasing both training accuracy and validation accuracy while reducing validation loss. The model also demonstrated higher confidence when predicting yoga poses, making the evidence-based wellness recommendation system more reliable.

# %%
print("Total Classes:", len(train_ds.class_names))
# Out:
# Total Classes: 107

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, models

base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(107, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_6 (Rescaling)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_6      │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, models

base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(107, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_4 (Rescaling)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=3
)
# Out:
# Epoch 1/5
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 46s 203ms/step - accuracy: 0.0227 - loss: 4.6020 - val_accuracy: 0.0618 - val_loss: 4.3472
# Epoch 2/5
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.0740 - loss: 4.0918 - val_accuracy: 0.1369 - val_loss: 3.7698
# Epoch 3/5
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.1374 - loss: 3.6137 - val_accuracy: 0.1962 - val_loss: 3.3692
# Epoch 4/5
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - accuracy: 0.1833 - loss: 3.3039 - val_accuracy: 0.2387 - val_loss: 3.0856
# Epoch 5/5
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.2058 - loss: 3.0727 - val_accuracy: 0.2755 - val_loss: 2.9123

# %%
class_names = train_ds.class_names
print(class_names[:10])
# Out:
# ['adho mukha svanasana', 'adho mukha vriksasana', 'agnistambhasana', 'ananda balasana', 'anantasana', 'anjaneyasana', 'ardha bhekasana', 'ardha chandrasana', 'ardha matsyendrasana', 'ardha pincha mayurasana']

# %% [markdown]
# # Yoga Pose Classification with Evidence-Based Wellness Recommendations
#
# ## Objective
#
# The objective of this project is to classify yoga poses using deep transfer learning and provide evidence-based wellness recommendations, potential health-related benefits, and safety precautions for each predicted pose.
#
# ## Research Goal
#
# To develop a deep learning-based yoga pose classification system and extend it with an evidence-based wellness recommendation layer.
#
# ## Dataset
#
# - Dataset: Yoga Pose Image Classification Dataset
# - Total Images: 5,993
# - Total Classes: 107
#
# ## Methodology
#
# - Image preprocessing
# - Transfer Learning using InceptionV3
# - Yoga pose classification
# - Wellness recommendation generation
#
# ## Results
#
# Current validation accuracy after 5 epochs: 27.88%
#
# ## Future Work
#
# - Improve classification accuracy
# - Add more evidence-based wellness information
# - Develop a real-time yoga pose recognition application

# %% [markdown]
# ## Model Performance
#
# The InceptionV3 transfer learning model was trained on 5,993 yoga pose images belonging to 107 classes.
#
# Training Accuracy (Epoch 5): 21.98%
# Validation Accuracy (Epoch 5): 27.88%
#
# The results demonstrate that transfer learning can successfully learn discriminative features for yoga pose classification. Future work will focus on improving accuracy through fine-tuning, data augmentation, and enhanced preprocessing techniques.

# %%
benefit_info = {

    "balasana": {
        "benefits": "Promotes relaxation and gentle stretching.",
        "conditions": [
            "Stress",
            "Anxiety",
            "Sleep quality"
        ],
        "breathing": "Take slow, deep breaths through the nose while relaxing the body into the pose.",
"precautions": "Avoid prolonged practice if you have severe knee injuries.",
"reference": "Peer-reviewed yoga literature"
        
        
    },

    "savasana": {
        "benefits": "Deep relaxation and breathing awareness.",
        "conditions": [
            "Stress",
            "Anxiety",
            "Blood pressure management"
        ],
        "breathing": "Breathe slowly and naturally through the nose, allowing the breath to become calm and effortless.",
    "precautions": "Generally safe for most practitioners. Use support under the knees or head if needed for comfort.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
       
    },

    "padmasana": {
        "benefits": "Supports meditation and concentration.",
        "conditions": [
            "Stress",
            "Mental focus",
            "Anxiety"
        ],
        "breathing": "Maintain slow, deep diaphragmatic breathing throughout the pose.",
    "precautions": "Avoid if you have knee or hip injuries or discomfort. Do not force the legs into position.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
    },

    "vajrasana": {
        "benefits": "Supports digestion and mindfulness.",
        "conditions": [
            "Digestive discomfort",
            "Stress"
        ],
        "breathing": "Breathe slowly and deeply through the nose while maintaining an upright spine.",
    "precautions": "Avoid prolonged practice if you have severe knee pain or recent ankle injuries.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
    },

    "bhujangasana": {
    "benefits": "...",
    "conditions": [...],
    "difficulty": "Beginner",
    "hold_time": "20–30 seconds",
    "target_muscles": [
        "Spine",
        "Chest",
        "Shoulders"
    ],
    "breathing": "Inhale while lifting the chest and exhale while returning to the starting position.",
"precautions": "Avoid if you have severe back injuries.",
"reference": "Peer-reviewed yoga literature"
},
    


"supta baddha konasana": {
    "benefits": "Promotes deep relaxation and gentle hip opening.",
    "conditions": [
        "Stress",
        "Anxiety",
        "Mild fatigue",
        "Relaxation"
    ],
    "breathing": "Practice slow, gentle breathing through the nose, allowing the body to fully relax.",
"precautions": "Avoid prolonged practice if you have hip or groin injuries.",
"reference": "Evidence summarized from peer-reviewed yoga literature."
},
    "supta virasana": {
    "benefits": "May support relaxation and gentle stretching of the thighs and hips.",
    "conditions": [
        "Stress",
        "Mild fatigue",
        "Relaxation"
    ],
    "breathing": "Maintain slow, steady breathing while gently opening the thighs and hips.",
"precautions": "Avoid or modify if you have knee, ankle, or lower back injuries.",
"reference": "Evidence summarized from peer-reviewed yoga literature."
},
    "tadasana": {
    "benefits": "Supports posture, balance, and body alignment.",
    "conditions": [
        "Poor posture",
        "Balance issues",
        "Body awareness"
    ],
    "breathing": "Take slow, even breaths while standing tall and maintaining body alignment.",
"precautions": "Use caution if you have dizziness or balance problems.",
"reference": "Evidence summarized from peer-reviewed yoga literature."
},
    "dhanurasana": {
    "benefits": "May support front-body stretching, spinal extension, and chest opening.",
    "conditions": [
        "Postural flexibility",
        "General mobility",
        "Spinal flexibility"
    ],
    "breathing": "Inhale while lifting the chest and legs, then breathe steadily while holding the pose.",
    "precautions": "Avoid or modify if you have a hernia, recent abdominal surgery, pregnancy, or significant back injury.",
    "reference": "NCCIH: Yoga Effectiveness and Safety"
},
    "vriksasana": {
    "benefits": "May improve balance, stability, posture, and concentration.",
    "conditions": [
        "Balance",
        "Postural stability",
        "Focus",
        "Body awareness"
    ],
    "breathing": "Take slow, steady breaths through the nose while focusing on a fixed point.",
    "precautions": "Use a wall for support if you have balance difficulties or dizziness.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "ardha matsyendrasana": {
    "benefits": "May improve spinal mobility, support posture, and gently stretch the back and hips.",
    "conditions": [
        "Back stiffness",
        "Postural flexibility",
        "General mobility",
        "Stress"
    ],
    "breathing": "Inhale to lengthen the spine, then exhale gently into the twist.",
    "precautions": "Avoid or modify if you have a recent spinal injury, severe back pain, or are pregnant unless advised by a qualified instructor.",
    "reference": "NCCIH: Yoga Effectiveness and Safety; Peer-reviewed yoga literature"
},
    "virabhadrasana i": {
    "benefits": "May improve lower-body strength, balance, posture, and hip flexibility.",
    "conditions": [
        "Postural stability",
        "Balance",
        "Hip flexibility",
        "Leg strength"
    ],
        "breathing": "Inhale while reaching the arms upward and breathe steadily while holding the lunge.",
    "precautions": "Use caution if you have knee, hip, or shoulder injuries. Modify the stance if you have balance difficulties.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
"virabhadrasana ii": {
    "benefits": "May improve leg strength, balance, stamina, and hip opening.",
    "conditions": [
        "Balance",
        "Lower-body strength",
        "Hip flexibility",
        "Postural stability"
    ],
    "breathing": "Maintain slow, steady breathing through the nose while keeping the chest open and shoulders relaxed.",
    "precautions": "Use caution if you have knee, hip, or shoulder injuries. Reduce the stance width if balance is difficult.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "gomukhasana": {
    "benefits": "May improve shoulder mobility, chest opening, hip flexibility, and overall posture.",
    "conditions": [
        "Shoulder stiffness",
        "Hip flexibility",
        "Postural improvement",
        "Stress management"
    ],
     "breathing": "Breathe slowly through the nose while keeping the spine tall and shoulders relaxed.",
    "precautions": "Use caution if you have shoulder, knee, or hip injuries. Modify the pose if you experience pain.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "adho mukha svanasana": {
    "benefits": "May improve flexibility, strengthen the shoulders and legs, and promote full-body stretching.",
    "conditions": [
        "Hamstring flexibility",
        "Shoulder mobility",
        "Postural alignment",
        "Stress management"
    ],
   "breathing": "Take slow, deep breaths through the nose while lengthening the spine and pressing the heels toward the floor.",
    "precautions": "Use caution if you have wrist pain, shoulder injuries, glaucoma, or uncontrolled high blood pressure. Modify the pose if needed.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "ustrasana": {
    "benefits": "May improve spinal flexibility, open the chest, strengthen the back muscles, and support posture.",
    "conditions": [
        "Postural improvement",
        "Chest mobility",
        "Spinal flexibility",
        "Stress management"
    ],
    "breathing": "Inhale to lift and open the chest, then breathe steadily while keeping the neck comfortable.",
    "precautions": "Use caution if you have neck pain, lower back injuries, dizziness, or uncontrolled high blood pressure. Modify the pose if needed.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
"setu bandha sarvangasana": {
    "benefits": "May strengthen the back, gluteal muscles, and legs while improving spinal mobility and chest expansion.",
    "conditions": [
        "Back stiffness",
        "Postural improvement",
        "Hip flexibility",
        "Stress management"
    ],
    "breathing": "Inhale while lifting the hips and breathe steadily through the nose while holding the pose.",
    "precautions": "Use caution if you have neck, shoulder, or lower back injuries. Avoid forcing the pose beyond a comfortable range.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"},
    "sukhasana": {
    "benefits": "May promote relaxation, mindfulness, comfortable seated meditation, and healthy posture.",
    "conditions": [
        "Stress management",
        "Anxiety",
        "Meditation",
        "Mental focus"
    ],
    "precautions": "Use cushions or blocks if you have hip or knee discomfort. Avoid prolonged sitting if it causes pain.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "marjaryasana": {
    "benefits": "May improve spinal mobility, posture, flexibility, and gentle back stretching.",
    "conditions": [
        "Back stiffness",
        "Neck mobility",
        "Postural flexibility",
        "General mobility"
    ],
    "breathing": "Exhale while rounding the spine upward and gently drawing the chin toward the chest.",
    "precautions": "Move gently if you have wrist pain or spinal injuries. Avoid movements that increase pain.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
    "bitilasana": {
    "benefits": "May improve spinal flexibility, chest opening, posture, and breathing mechanics.",
    "conditions": [
        "Back stiffness",
        "Postural improvement",
        "Chest mobility",
        "General flexibility"
    ],
    "breathing": "Inhale while lifting the chest and tailbone, allowing the abdomen to gently expand.",
    "precautions": "Practice gently if you have neck or lower back pain. Avoid excessive spinal extension.",
    "reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
    },
    "utkatasana": {
    "benefits": "May strengthen the thighs, gluteal muscles, and core while improving balance and posture.",
    "conditions": [
        "Lower-body strength",
        "Balance",
        "Postural stability",
        "General fitness"
    ],
    "breathing": "Inhale to lengthen the spine and exhale while bending the knees into the pose.",
"precautions": "Use caution if you have knee pain, ankle injuries, or lower back discomfort. Modify the depth of the squat if needed.",
"reference": "National Center for Complementary and Integrative Health (NCCIH); Peer-reviewed yoga literature"
},
"utthita parsvakonasana": {
    "benefits": "Strengthens the legs, improves balance, and increases flexibility in the hips and spine.",
    "conditions": [
        "Poor balance",
        "Hip stiffness",
        "Leg strength"
    ],
    "difficulty": "Intermediate",
    "hold_time": "20–30 seconds",
    "target_muscles": [
        "Legs",
        "Hips",
        "Core",
        "Shoulders"
    ],
        "breathing": "Inhale to lengthen the spine, then exhale while deepening the side stretch.",
    "precautions": "Avoid if you have acute knee or hip injuries. Modify if you have balance difficulties.",
    "reference": "Evidence summarized from peer-reviewed yoga literature."
},
}


print("Wellness database loaded successfully!")
print("Number of poses:", len(benefit_info))
# Out:
# Wellness database loaded successfully!
# Number of poses: 22

# %% [markdown]
# ## Wellness Recommendation Database
#
# To extend the yoga pose classification model, an evidence-based wellness recommendation database has been created. For each yoga pose, the database stores:
#
# - Potential wellness benefits
# - Health conditions the pose may support
# - Safety precautions
# - Reference information
#
# This information is intended for educational purposes and is not a substitute for professional medical advice.

# %% [markdown]
# # Pose Prediction and Wellness Recommendation
#
# After predicting a yoga pose, the trained deep learning model retrieves corresponding wellness information from the evidence-based recommendation database. The system displays:
#
# - Predicted yoga pose
# - Potential wellness benefits
# - Conditions the pose may support
# - Safety precautions
# - Literature reference

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
class_names = train_ds.class_names
print("Total Yoga Classes:", len(class_names))
print(class_names[:10])
# Out:
# Total Yoga Classes: 107
# ['adho mukha svanasana', 'adho mukha vriksasana', 'agnistambhasana', 'ananda balasana', 'anantasana', 'anjaneyasana', 'ardha bhekasana', 'ardha chandrasana', 'ardha matsyendrasana', 'ardha pincha mayurasana']

# %%
for images, labels in val_ds.take(1):

    image = images[0]
    true_label = labels[0]

    prediction = model.predict(tf.expand_dims(image, axis=0))

predicted_index = np.argmax(prediction)
predicted_pose = class_names[predicted_index]

confidence = np.max(prediction) * 100

print("Pose:", predicted_pose)
print(f"Prediction Confidence: {confidence:.2f}%")


plt.figure(figsize=(5,5))
plt.imshow(image.numpy().astype("uint8"))
plt.axis("off")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Pose: adho mukha svanasana
# Prediction Confidence: 10.04%

# %%
print("Predicted Pose:", predicted_pose)

print("\nAvailable poses in database:")
print(list(benefit_info.keys()))

if predicted_pose in benefit_info:

    info = benefit_info[predicted_pose]

    print("\n===== Wellness Recommendation =====")
    print("Pose:", predicted_pose)

    print("\nBenefits:")
    print(info["benefits"])

    print("\nDifficulty:")
    print(info.get("difficulty", "Not Available"))

    print("\nRecommended Hold Time:")
    print(info.get("hold_time", "Not Available"))

    print("\nTarget Muscles:")
    for muscle in info.get("target_muscles", []):
        print("•", muscle)

    print("\nBreathing Technique:")
    print(info.get("breathing", "Not Available"))

    print("\nMay Help With:")
    for condition in info["conditions"]:
        print("•", condition)

    print("\nPrecautions:")
    print(info["precautions"])

    print("\nReference:")
    print(info["reference"])

else:
    print("\n❌ No wellness information available for:", predicted_pose)
# Out:
# Predicted Pose: adho mukha svanasana
#
# Available poses in database:
# ['balasana', 'savasana', 'padmasana', 'vajrasana', 'bhujangasana', 'supta baddha konasana', 'supta virasana', 'tadasana', 'dhanurasana', 'vriksasana', 'ardha matsyendrasana', 'virabhadrasana i', 'virabhadrasana ii', 'gomukhasana', 'adho mukha svanasana', 'ustrasana', 'setu bandha sarvangasana', 'sukhasana', 'marjaryasana', 'bitilasana', 'utkatasana', 'utthita parsvakonasana']
#
# ===== Wellness Recommendation =====
# Pose: adho mukha svanasana
#
# Benefits:
# May improve flexibility, strengthen the shoulders and legs, and promote full-body stretching.
#
# Difficulty:
# Not Available
#
# Recommended Hold Time:
# Not Available
#
# Target Muscles:
#
# Breathing Technique:
# Not Available
#
# May Help With:
# • Hamstring flexibility
# • Shoulder mobility
# • Postural alignment
# • Stress management
#
# Precautions:
# ...

# %%
print("Predicted Pose:", repr(predicted_pose))

print("\nKeys in benefit_info:")
for key in benefit_info.keys():
    print(repr(key))
# Out:
# Predicted Pose: 'viparita karani'
#
# Keys in benefit_info:
# 'balasana'
# 'savasana'
# 'padmasana'
# 'vajrasana'
# 'bhujangasana'
# 'supta baddha konasana'
# 'supta virasana'
# 'tadasana'
# 'dhanurasana'
# 'vriksasana'
# 'ardha matsyendrasana'
# 'virabhadrasana i'
# 'virabhadrasana ii'
# 'gomukhasana'
# 'adho mukha svanasana'
# 'ustrasana'
# 'setu bandha sarvangasana'
# 'sukhasana'
# 'marjaryasana'
# 'bitilasana'
# 'utkatasana'
# 'utthita parsvakonasana'

# %% [markdown]
# # Scientific References
#
# The wellness recommendations included in this notebook are intended for educational purposes and are based on published scientific literature and reputable health resources.
#
# Current sources include:
#
# 1. National Center for Complementary and Integrative Health (NCCIH)
# 2. PubMed
# 3. Peer-reviewed yoga research articles
# 4. World Health Organization (WHO) Physical Activity Guidelines
#
# As the project progresses, each yoga pose recommendation will be updated with pose-specific scientific references.

# %% [markdown]
# ## Disclaimer
#
# The wellness recommendations provided by this system are intended for educational and research purposes only. They should not be interpreted as medical advice, diagnosis, or treatment. Users should consult qualified healthcare professionals before beginning any exercise or wellness program.

# %%
# Save the fine-tuned model
model.save("yoga_pose_classifier_v2.keras")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
print(model)
# Out:
# <Sequential name=sequential_2, built=True>

# %%
print(base_model)
print(model)
# Out:
# <Functional name=inception_v3, built=True>
# <Sequential name=sequential_2, built=True>
